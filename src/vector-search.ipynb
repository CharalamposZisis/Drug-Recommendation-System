# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_chroma import Chroma

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import os

access_token = os.getenv("HF_TOKEN")

tokenizer = AutoTokenizer.from_pretrained(
    "google/flan-t5-large",
    token=access_token
)

model = AutoModelForSeq2SeqLM.from_pretrained(
    "google/flan-t5-large"
)
# Out:
# Loading weights: 100%|██████████| 558/558 [00:00<00:00, 3412.60it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.

# %%
import sys

# !{sys.executable} -m pip install -U "transformers[torch]"
# Out:
# Requirement already satisfied: transformers[torch] in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (5.15.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (1.27.0)
# Requirement already satisfied: numpy>=1.17 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (2026.7.19)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (0.27.1)
# Requirement already satisfied: safetensors>=0.8.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (4.70.0)
# Requirement already satisfied: torch>=2.5 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (2.13.0)
# Requirement already satisfied: accelerate>=1.1.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from transformers[torch]) (1.14.0)
# Requirement already satisfied: psutil in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from accelerate>=1.1.0->transformers[torch]) (7.2.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (84.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.3 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (13.0.3.0)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from torch>=2.5->transformers[torch]) (3.7.1)
# Requirement already satisfied: nvidia-cublas==13.1.1.3.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (13.1.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (12.0.0.61)
# Requirement already satisfied: nvidia-nvjitlink<14,>=13.0.88 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (13.3.33)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (12.6.3.3)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.5->transformers[torch]) (13.0.85)
# Requirement already satisfied: shellingham>=1.3.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from typer->transformers[torch]) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from typer->transformers[torch]) (0.0.5)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.5->transformers[torch]) (1.6.0)
# Requirement already satisfied: anyio in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.14.2)
# Requirement already satisfied: certifi in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.0.9)
# Requirement already satisfied: idna in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from rich>=13.8.0->typer->transformers[torch]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from rich>=13.8.0->typer->transformers[torch]) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.5->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from jinja2->torch>=2.5->transformers[torch]) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/charis/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers[torch]) (0.1.2)

# %%
raw_documents = TextLoader("src/cleaned_csv").load()
text_splitter = CharacterTextSplitter(chunk_size=0, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages/langchain_community/document_loaders/text.py:42, in TextLoader.lazy_load(self)
#      41 try:
# ---> 42     with open(self.file_path, encoding=self.encoding) as f:
#      43         text = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'src/cleaned_csv'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 raw_documents = TextLoader("src/cleaned_csv").load()
#       2 text_splitter = CharacterTextSplitter(chunk_size=0, chunk_overlap=0, separator="\n")
#       3 documents = text_splitter.split_documents(raw_documents)
#
# File ~/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages/langchain_core/document_loaders/base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File ~/Desktop/Projects/Drug-Recommendation-System/vevn/lib/python3.12/site-packages/langchain_community/document_loaders/text.py:58, in TextLoader.lazy_load(self)
#      56         raise RuntimeError(f"Error loading {self.file_path}") from e
#      57 except Exception as e:
# ---> 58     raise RuntimeError(f"Error loading {self.file_path}") from e
#      60 metadata = {"source": str(self.file_path)}
#      61 yield Document(page_content=text, metadata=metadata)
#
# RuntimeError: Error loading src/cleaned_csv
